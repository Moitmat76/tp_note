# %% [markdown]
# algo
# definir une fonction qui calcule la moyenne UE
# on creer 3 variables UE1 UE2 et UE3
# demander à l'utilisateur dans quelle UE il est
#     Si il est dans l'UE 1
#     alors demander ces notes dans les ressources et les SAE et demander les coeff
#         calculer la moyenne
#         si le resultat >= 10 alors afficher la moyenne plus une pastille verte
#         si le resultat compris entre 8 et 10 alors afficher la moyenne plus une pastille orange
#         si le resultat < 10 alors afficher la moyenne plus une pastille rouge
#
#     Si il est dans l'UE 2
#     alors demander ces notes dans les ressources et les SAE et demander les coeff
#         calculer la moyenne
#         si le resultat >= 10 alors afficher la moyenne plus une pastille verte
#         si le resultat compris entre 8 et 10 alors afficher la moyenne plus une pastille orange
#         si le resultat < 10 alors afficher la moyenne plus une pastille rouge
#     Si il est dans l'UE 3
#     alors demander ces notes dans les ressources et les SAE et demander les coeff
#         calculer la moyenne
#         si le resultat >= 10 alors afficher la moyenne plus une pastille verte
#         si le resultat compris entre 8 et 10 alors afficher la moyenne plus une pastille orange
#         si le resultat < 10 alors afficher la moyenne plus une pastille rouge

# %%
moy_1=0
coe_1=0
som_1=0
coe_2=0
som_2=0
UE=int(input("donnez-moi votre UE"))
if UE==1:
    for i in range(101,103):
        note=float(input("donnez-moi la note de la ressources R{}".format(i)))
        coeff=int(input("donnez-moi le coeff de la ressources R{}".format(i)))
        som_1+=note*coeff
        coe_1+=coeff
    for i in range (11,13):
        note=float(input("donnez-moi la note de la ressources SAE{}".format(i)))
        coeff=int(input("donnez-moi le coeff de la ressources SAE{}".format(i)))
        som_2+=note*coeff
        coe_2+=coeff
    moy_1=som_1/coe_1
    print(moy_1)
elif UE==2:
    for i in range(101,103):
        note=float(input("donnez-moi la note de la ressources R{}".format(i)))
        coeff=int(input("donnez-moi le coeff de la ressources R{}".format(i)))
        som_1+=note*coeff
        coe_1+=coeff
    for i in range (11,13):
        note=float(input("donnez-moi la note de la ressources SAE{}".format(i)))
        coeff=int(input("donnez-moi le coeff de la ressources SAE{}".format(i)))
        som_2+=note*coeff
        coe_2+=coeff
    moy_1=som_1/coe_1
    print(moy_1)
else:
    for i in range(101,103):
        note=float(input("donnez-moi la note de la ressources R{}".format(i)))
        coeff=int(input("donnez-moi le coeff de la ressources R{}".format(i)))
        som_1+=note*coeff
        coe_1+=coeff
    for i in range (11,13):
        note=float(input("donnez-moi la note de la ressources SAE{}".format(i)))
        coeff=int(input("donnez-moi le coeff de la ressources SAE{}".format(i)))
        som_2+=note*coeff
        coe_2+=coeff
    moy_1=som_1/coe_1
    print(moy_1)
# Out:
# donnez-moi votre UE 2
# donnez-moi la note de la ressources R101 18
# donnez-moi le coeff de la ressources R101 10
# donnez-moi la note de la ressources R102 15
# donnez-moi le coeff de la ressources R102 7
# donnez-moi la note de la ressources SAE11 20
# donnez-moi le coeff de la ressources SAE11 8
# donnez-moi la note de la ressources SAE12 14
# donnez-moi le coeff de la ressources SAE12 5
# 16.764705882352942
